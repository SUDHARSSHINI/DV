# %% [markdown]
# <a href="https://colab.research.google.com/github/SUDHARSSHINI/DV/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6,10,5,7,8])
ypoints = np.array([0,25,5,80,6,800])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,3,8,3,8,3])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,3,8,3,8,3])
plt.plot(ypoints,marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,3,8,3,8,3])
plt.plot(ypoints,'*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,3,8,3,8,3])
plt.plot(ypoints,linestyle='dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,3,8,3,8,3])
plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,3,4])
ypoints=np.array([3,4,5])
plt.plot(xpoints,ypoints,linestyle='dotted')
plt.show()
